# %% [markdown]
# # Logistic Regression from a Neural Networks Perspective

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Sigmoid Activation Function

# %%
x = np.linspace(-5, 5, 100)

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

s = sigmoid(x)
plt.plot(x, s)

# %% [markdown]
# ## Cross-entropy Loss Function

# %%
x = np.linspace(0, 1, 100)
Ly1 = - np.log(x) # Loss if the true y is 1
# Out:
# /home/joerg/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
plt.plot(x, Ly1)

# %%
Ly0 = - np.log(1-x) # Loss if the true y is 0
# Out:
# /home/joerg/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(x, Ly0)
